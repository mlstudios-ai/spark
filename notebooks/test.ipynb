# %%
import sys
import os

# Add the /app/src directory to the Python path
sys.path.append(os.path.abspath('../app/src'))

# # Now try importing again
# from spark.data import loader
# from spark.data.models import Customer, Product, Interaction, Category

# %%
# %reload_ext tensorboard

# %%
logs_dir = 'output/spark/logs'
# %tensorboard --logdir {logs_dir}
# Out:
# Reusing TensorBoard on port 6022 (pid 51294), started 0:00:09 ago. (Use '!kill 51294' to kill it.)
#       <iframe id="tensorboard-frame-47419311a232b21c" width="100%" height="800" frameborder="0">
#       </iframe>
#       <script>
#         (function() {
#           const frame = document.getElementById("tensorboard-frame-47419311a232b21c");
#           const url = new URL("http://localhost");
#           const port = 6022;
#           if (port) {
#             url.port = port;
#           }
#           frame.src = url;
#         })();
#       </script>
